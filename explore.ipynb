# %%
import census_lib as cl

# %%
cl.variables('B01001')
# Out:
# {'B01001_047EA': {'label': 'Annotation of Estimate!!Total:!!Female:!!75 to 79 years',
#   'concept': 'Sex by Age',
#   'predicateType': 'string',
#   'group': 'B01001',
#   'limit': 0,
#   'predicateOnly': True,
#   'universe': 'Total population'},
#  'B01001_047MA': {'label': 'Annotation of Margin of Error!!Total:!!Female:!!75 to 79 years',
#   'concept': 'Sex by Age',
#   'predicateType': 'string',
#   'group': 'B01001',
#   'limit': 0,
#   'predicateOnly': True,
#   'universe': 'Total population'},
#  'B01001_046EA': {'label': 'Annotation of Estimate!!Total:!!Female:!!70 to 74 years',
#   'concept': 'Sex by Age',
#   'predicateType': 'string',
#   'group': 'B01001',
#   'limit': 0,
#   'predicateOnly': True,
#   'universe': 'Total population'},
#  'B01001_046MA': {'label': 'Annotation of Margin of Error!!Total:!!Female:!!70 to 74 years',
#   'concept': 'Sex by Age',
#   'predicateType': 'string',
#   'group': 'B01001',
#   'limit': 0,
#   'predicateOnly': True,
# ...
